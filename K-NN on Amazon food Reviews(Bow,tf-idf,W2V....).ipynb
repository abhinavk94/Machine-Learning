# %% [markdown]
# # Classification of Amazon Food Reviews using KNN classification techniques
#     There are many ways to convert Word to vector out of which these 4 are considered and applied to see which gives the best accuracy on the test data.
#     1) BoW
#     2) AvgW2V
#     3) Tf-idf
#     4) Tf-idf Weighted AvgW2V

# %%
# importing the required libraries.

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import sqlite3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import nltk
import seaborn as sns
import string

#from sklearn.feature_extraction.text import TfidfTransformer
#from sklearn.feature_extraction.text import TfidfVectorizer
#from sklearn.feature_extraction.text import CountVectorizer
#from sklearn.metrics import confusion_matrix
#from sklearn import metrics
#from sklearn.metrics import roc_curve, auc
from nltk.stem.porter import PorterStemmer

import re
# Tutorial about Python regular expressions: https://pymotw.com/2/re/
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer

from gensim.models import Word2Vec
from gensim.models import KeyedVectors
import pickle

from tqdm import tqdm
import os

# %%
# establishing a secure connection to the database.

con = sqlite3.connect("/Users/abhinavkunta/Desktop/DataSets/amazon-fine-food-reviews/database.sqlite")

# %%
# considering reviews which are positive or negative and ignoring the neutral reviews.
filtered_data = pd.read_sql_query("SELECT * FROM Reviews WHERE Score  != 3",con)

# %%
df = pd.read_sql_query("SELECT * FROM Reviews WHERE HelpfulnessNumerator > HelpfulnessDenominator",con)

# %%
df
# Out:
#       Id   ProductId          UserId              ProfileName  \
# 0  44737  B001EQ55RW  A2V0I904FH7ABY                      Ram
# 1  64422  B000MIDROQ  A161DK06JJMCYF  J. E. Stephens "Jeanne"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     3                       2      4  1212883200
# 1                     3                       1      5  1224892800
#
#                                         Summary  \
# 0  Pure cocoa taste with crunchy almonds inside
# 1             Bought This for My Son at College
#
#                                                 Text
# 0  It was almost a 'love at first bite' - the per...
# 1  My son loves spaghetti so I didn't hesitate or...

# %%
# giving a rating according to the score
def partition(x):
    if x < 3:
        return 'negative'
    return 'positive'

#changing reviews with score less than 3 to be positive and vice-versa
rating = filtered_data['Score']
positiveneg = rating.map(partition) 
filtered_data['Score'] = positiveneg

# %%
filtered_data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator     Score        Time  \
# 0                     1                       1  positive  1303862400
# 1                     0                       0  negative  1346976000
# 2                     1                       1  positive  1219017600
# 3                     3                       3  negative  1307923200
# 4                     0                       0  positive  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
# data deduplication
final = filtered_data.drop_duplicates(subset={"UserId","ProfileName","Time","Text"}, keep='first', inplace=False)

# %%
final.shape
# Out:
# (364173, 10)

# %%
final = final[final.HelpfulnessNumerator <= final.HelpfulnessDenominator]

# %%
# here we are only considering the subset of reviews by random sampling as it is lot of time consuming for 500k reviews.

# sampling the positive reviews
finalp = final[final.Score == 'positive']
finalp = finalp.sample(frac=0.035,random_state=1) 

# sampling the negative reviews
finaln = final[final.Score == 'negative']
finaln = finaln.sample(frac=0.15,random_state=1) 

# concatinating both the samples
final = pd.concat([finalp,finaln],axis=0)

# %%
final.shape
# Out:
# (19313, 10)

# %%
# sorting is done according to time because the reviews change by time-time and more over we havevtimestamps available.

final = final.sort_values("Time",axis=0,kind="quicksort", ascending=True).reset_index(drop=True)

# %%
final.head() # sorted according to the time stamp
# Out:
#        Id   ProductId          UserId       ProfileName  HelpfulnessNumerator  \
# 0  230265  B00004RYGX   AZRJH4JFB59VC  Lynwood E. Hines                    21
# 1  230283  B00004RYGX  A31RM5QU797HPJ              Drez                     1
# 2  151400  B0000DHZY1   AJ6ZYWQ5C2RSX        Sue Thomas                     0
# 3  333669  B0000UBTYG   A6BS5D5YPF2HW                MT                     3
# 4  165710  B0000D9N59  A1IU7S4HCK1XK0    Joanna Daneman                    45
#
#    HelpfulnessDenominator     Score        Time  \
# 0                      23  negative   997228800
# 1                       2  positive  1024531200
# 2                       0  negative  1068508800
# 3                       3  positive  1072137600
# 4                      48  positive  1072656000
#
#                                          Summary  \
# 0                      Great movie, terrible DVD
# 1  &quot;I'm the ghost with the most, babe&quot;
# 2                               This is not pure
# 3                                A Great Chai!!!
# 4                       Best cheese in the world
#
#                                                 Text
# 0  I am continually amazed at the shoddy treatmen...
# 1  Simply put: Beetlejuice is the funniest comedy...
# 2  I have baked with this organic vanilla in the ...
# 3  I think that this is a great Chai! Far from sw...
# 4  I surprise myself by rating this cheese my fav...

# %%
# checking the number of positiveb and negative ratings.

final['Score'].value_counts()
# Out:
# positive    10747
# negative     8566
# Name: Score, dtype: int64

# %%
# preprocessing = stopword removal, stemming, lemmitization.
# removal of html tags
import re
i=0;
for sent in final['Text'].values:
    if (len(re.findall('<.*?>', sent))):
        print(i)
        print(sent)
        break;
    i += 1;
# Out:
# 0
# I am continually amazed at the shoddy treatment that some movies get in their DVD release.  This DVD is simply a disgrace, especially considering what a great movie this is.  I give the movie itself 5 stars; it's a wonderful example of Tim Burton's energy and style.<p>This DVD has no extras worth mentioning.  No deleted scenes, no featurettes, not even a lousy commentary track!  To make it even worse, the film has been CUT DOWN from the theatrical release!  I have never seen a DVD release before where you get LESS than was originally presented in theaters.<p>My advice is to save your money until somebody figures out that when a movie is released on DVD, it needs to live up to the capabilities of the medium, and should always provide more material than was originally released, not less.

# %%
# downloading set of stopwords in english
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/abhinavkunta/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# set of stop words
stop = set(stopwords.words('english'))
print(stop)
# Out:
# {'doesn', "don't", 'ourselves', 'from', 't', 'who', 'as', "isn't", 'them', 'their', 'again', "aren't", 'other', 'won', "you're", 'about', 'nor', 'being', 'themselves', "weren't", 'himself', 'hadn', 'can', 'shan', 'but', 'ain', 'your', 'some', 'y', 'yourself', 'they', 'or', 'and', 'until', 'off', 'has', 'him', "shan't", "won't", 'over', 'itself', 'that', 'for', "couldn't", 'only', "hadn't", 'am', 'd', 'my', 'whom', "haven't", 'ours', 'these', 'out', 'll', 'if', 'needn', 'those', 'through', 'didn', "shouldn't", 'with', "should've", 'our', 'have', 'this', 'haven', 'both', 'own', "she's", 'theirs', 'here', 'which', 'very', 'above', 'did', 'its', 'when', 'further', "hasn't", "didn't", 'how', 'the', 'up', 'below', 'where', 'myself', 'were', 'herself', 'is', "wasn't", 'wasn', 'does', 'before', 'was', "doesn't", 'during', 'no', 'an', 'of', 'ma', "you'll", 'his', 'more', 'there', 'not', 'than', 'what', 'be', 's', 'now', 'having', 'so', 'doing', 'such', 've', 'should', "wouldn't", 'any', 'on', "needn't", 'to', 'yours', 'aren', 'you', 'down', 'all', 'between', 'o', 'into', 'me', 'under', 'a', 'few', 'hers', "you've", 'couldn', "mightn't", "mustn't", 'we', 'why', 'while', 'm', 'wouldn', 'don', 'same', 'he', 'yourselves', 'been', 'mightn', 'against', 'then', 'shouldn', 'it', 'each', 'after', 'i', "you'd", 'she', 'once', 'too', 'hasn', "that'll", 're', 'because', 'in', 'most', 'isn', 'are', 'by', "it's", 'her', 'do', 'will', 'weren', 'mustn', 'had', 'just', 'at'}

# %%
# %%time
sno = nltk.stem.SnowballStemmer('english') #initialising the snowball stemmer

def cleanhtml(sentence): #function to clean the word of any html-tags
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, ' ', sentence)
    return cleantext
def cleanpunc(sentence): #function to clean the word of any punctuation or special characters
    cleaned = re.sub(r'[?|!|\'|"|#]',r'',sentence)
    cleaned = re.sub(r'[.|,|)|(|\|/]',r' ',cleaned)
    return  cleaned
print(stop)
print('************************************')
print(sno.stem('tasty'))
# Out:
# {'doesn', "don't", 'ourselves', 'from', 't', 'who', 'as', "isn't", 'them', 'their', 'again', "aren't", 'other', 'won', "you're", 'about', 'nor', 'being', 'themselves', "weren't", 'himself', 'hadn', 'can', 'shan', 'but', 'ain', 'your', 'some', 'y', 'yourself', 'they', 'or', 'and', 'until', 'off', 'has', 'him', "shan't", "won't", 'over', 'itself', 'that', 'for', "couldn't", 'only', "hadn't", 'am', 'd', 'my', 'whom', "haven't", 'ours', 'these', 'out', 'll', 'if', 'needn', 'those', 'through', 'didn', "shouldn't", 'with', "should've", 'our', 'have', 'this', 'haven', 'both', 'own', "she's", 'theirs', 'here', 'which', 'very', 'above', 'did', 'its', 'when', 'further', "hasn't", "didn't", 'how', 'the', 'up', 'below', 'where', 'myself', 'were', 'herself', 'is', "wasn't", 'wasn', 'does', 'before', 'was', "doesn't", 'during', 'no', 'an', 'of', 'ma', "you'll", 'his', 'more', 'there', 'not', 'than', 'what', 'be', 's', 'now', 'having', 'so', 'doing', 'such', 've', 'should', "wouldn't", 'any', 'on', "needn't", 'to', 'yours', 'aren', 'you', 'down', 'all', 'between', 'o', 'into', 'me', 'under', 'a', 'few', 'hers', "you've", 'couldn', "mightn't", "mustn't", 'we', 'why', 'while', 'm', 'wouldn', 'don', 'same', 'he', 'yourselves', 'been', 'mightn', 'against', 'then', 'shouldn', 'it', 'each', 'after', 'i', "you'd", 'she', 'once', 'too', 'hasn', "that'll", 're', 'because', 'in', 'most', 'isn', 'are', 'by', "it's", 'her', 'do', 'will', 'weren', 'mustn', 'had', 'just', 'at'}
# ************************************
# tasti
# CPU times: user 277 µs, sys: 77 µs, total: 354 µs
# Wall time: 288 µs

# %%
# %%time
import os

if not os.path.isfile('final.sqlite'):
    i=0
    str1=' '
    final_string=[]
    all_positive_words=[] # store words from +ve reviews here
    all_negative_words=[] # store words from -ve reviews here.
    s=''
    for sent in final['Text'].values:
        filtered_sentence=[]
        #print(sent);
        sent=cleanhtml(sent) # remove HTMl tags
        for w in sent.split():
            for cleaned_words in cleanpunc(w).split():
                if((cleaned_words.isalpha()) & (len(cleaned_words)>2)):    
                    if(cleaned_words.lower() not in stop):
                        s=(sno.stem(cleaned_words.lower())).encode('utf8')
                        filtered_sentence.append(s)
                        if (final['Score'].values)[i] == 'positive': 
                            all_positive_words.append(s) #list of all words used to describe positive reviews
                        if(final['Score'].values)[i] == 'negative':
                            all_negative_words.append(s) #list of all words used to describe negative reviews reviews
                    else:
                        continue
                else:
                    continue 
        #print(filtered_sentence)
        str1 = b" ".join(filtered_sentence) #final string of cleaned words
        #print("***********************************************************************")

        final_string.append(str1)
        i+=1
        final['CleanedText']=final_string #adding a column of CleanedText which displays the data after pre-processing of the review 
    final['CleanedText']=final['CleanedText'].str.decode("utf-8")
        # store final table into an SQlLite table for future.
    conn = sqlite3.connect('final.sqlite')
    c=conn.cursor()
    conn.text_factory = str
    final.to_sql('Reviews', conn,  schema=None, if_exists='replace', \
                 index=True, index_label=None, chunksize=None, dtype=None)
    conn.close()
    
    
    with open('positive_words.pkl', 'wb') as f:
        pickle.dump(all_positive_words, f)
    with open('negitive_words.pkl', 'wb') as f:
        pickle.dump(all_negative_words, f)
# Out:
# CPU times: user 64 µs, sys: 60 µs, total: 124 µs
# Wall time: 104 µs

# %%
# %%time
# this code takes a while to run as it needs to run on 500k sentences.
i=0
str1=' '
final_string=[]
all_positive_words=[] # store words from +ve reviews here
all_negative_words=[] # store words from -ve reviews here.
s=''
for sent in final['Text'].values:
    filtered_sentence=[]
    #print(sent);
    sent=cleanhtml(sent) # remove HTMl tags
    for w in sent.split():
        for cleaned_words in cleanpunc(w).split():
            if((cleaned_words.isalpha()) & (len(cleaned_words)>2)):    
                if(cleaned_words.lower() not in stop):
                    s=(sno.stem(cleaned_words.lower())).encode('utf8')
                    filtered_sentence.append(s)
                    if (final['Score'].values)[i] == 'positive': 
                        all_positive_words.append(s) #list of all words used to describe positive reviews
                    if(final['Score'].values)[i] == 'negative':
                        all_negative_words.append(s) #list of all words used to describe negative reviews reviews
                else:
                    continue
            else:
                continue 
    #print(filtered_sentence)
    str1 = b" ".join(filtered_sentence) #final string of cleaned words
    #print("***********************************************************************")
    
    final_string.append(str1)
    i+=1
# Out:
# CPU times: user 19.5 s, sys: 56.4 ms, total: 19.6 s
# Wall time: 19.7 s

# %%
final_string
# Out:
# [b'continu amaz shoddi treatment movi get dvd releas dvd simpli disgrac especi consid great movi give movi wonder exampl tim burton energi style dvd extra worth mention delet scene featurett even lousi commentari track make even wors film cut theatric releas never seen dvd releas get less origin present theater advic save money somebodi figur movi releas dvd need live capabl medium alway provid materi origin releas less',
#  b'simpli beetlejuic funniest comedi kind sinc ghostbust michael keaton play titl charact ghost like mischief beetlejuic call coupl davi baldwin get rid peopl live thier hous',
#  b'bake organ vanilla past realiz vanilla extract found product mislead even though categor organ product',
#  b'think great chai far sweet found unsweet exact like tiger spice great blend black tea cinnamon ginger herb big tea drinker smooth light chai add water come creami perfect peopl add milk chai mix alreadi creamer new healthi breakfast wake great mani indian friend drink fresh made chai close come instant blend high recommend',
#  b'surpris rate chees favorit chees love chees kind real parmigiano reggiano delici love characterist amino acid crunch littl white spot crystal amino acid produc ripen process even though pound grate last long time sad may discov real parmesan eaten chunk like good chocol thus pound melt away like snow good',
#  b'real parmigiano reggiano one great chees world best reggiano differ grade reggiano much grate chees eaten meal best grade reggiano best shaven use good chees plane slight pineappl tast savor slowli chees real treat',
#  b'realli pleas bonsai alreadi see go bloom soon look forward sight smell problem item receiv without plate shown pic amazon resent whole thing cant send part item still plate didnt come dont understand didnt get item way shown websit that piti quit disappoint',
#  b'lot muscl test found balein salt consist test better peopl salt celtic salt test well alway good product theori vet give cow salt lick farmer keep cattl healthi cant afford lot medicin book like bodi mani cri water also talk salt regular groceri store brand health food store brand test weak peopl keep health balanc lot water enough salt right salt',
#  b'enjoy hot coco must say best ever',
#  b'chees wonder arriv well chill tast wonder treat raclett year round extra freez well defrost without problem well worth cost need pay expens raclett perfect',
#  b'recent trip holland opportun experi excel senseo coffe like much upon return seattl immedi check machin avail unit state thrill find amazon com last week bought senseo machin along four box medium roast decaffein pod also receiv one packag regular medium roast one packag mild roast senseo machin horror coffe receiv poor substitut douw egbert coffe enjoy much holland coffe deliv weak tasteless fact get halfway decent coffe use two pod one cup unaccept point view expens also limit use machin one serv time request provid senseo coffe machin user qualiti coffe sell holland pod twice expens will pay coffe superior qualiti starbuck huge success countri sell real coffe version real thing receiv qualiti coffe substitut poor coffe tell friend neighbor colleagu anybodi els might interest invest senseo machin meantim would happi return coffe use pleas let know expect remedi situat hear within week return senseo machin remain unus portion coffe amazon com full refund look forward hear',
#  b'must respect disagre review medium roast coffe receiv senseo produc teriff cup coffe coffe shop like tast dark roast medium roast perfect everi day morn blend',
#  b'cat love dont know ever enjoy swallow whole tooth mark didnt realli get enjoy gooey center realli like otherwis chew coupl theyr realli small cat small mouth one would good choic buy cat bad teeth realli appreci good job keep teeth clean dont brush often love',
#  b'extrem tasti mustard seed add nice nubbl textur seed hard fantast melt bread drawback want eat one sit',
#  b'pickl like much acquir tast acquir tast amount addict even obsess pickl add incred depth complex almost dish one caveat concern salt diet mani peopl cardiac problem kind condiment pose obvious risk take except care use safe spoke memori inaccur late evauat deep hot mango chutney let correct tablespoon contain sodium priya mix pickl amount contain priya prais absolut authent web actual prefer',
#  b'bought senseo machin conveni make one cup time underwhelm coffe choic avail found kona coffe pod aloha island use cost littl worth everi penni want smooth rich cup pure kona coffe one buy',
#  b'sauc well bad grant differ gazillion hot sauc spici seem flavor food slight aftertast rot veget',
#  b'receiv one bavaria ham gift glaze ham love though friend nice person invit friend ham asparagus big pile yukon gold potato salad sinc hotter blaze insid decid heat ham roast asparagus potato bbq slather ham secret bbq sauc place cooler side grill hour later sit patio big hot delici bbqd ham stare face french rose pour meal consum good time',
#  b'mani black tea yunnan strong stark find tea like assam ceylon herb real treat first make bone black tea strong bitter tast look forward black tea howev aroma incred clove cinnamon almost youv open box christma tea rich dark produc littl froth main think leav broken youll want fine filter sediment filter use tea strong charact clove orang cinnamon make tea much spici spici enough detract rest tea certain enough get attent box mention kind cinnamon tea well much believ know least two kind sri lanka madagascar cinnamon seem reason third might ad sweet flavor review mention realli amaz tea think peopl find go quick nice break standard black tea fare that normal drink compar rishi tea fire anoth spici tea big differ bodi rishi offer light boodi wherea tea almost tast like molass ad yum spice charact boot high recommend',
#  b'recent purchas anchovi stuf oliv hard find let alon tast anchovi oliv jar name wish anchovi stuf oliv unfortun funni martini group continu search anchovi stuf oliv substanc',
#  b'realli want make impact send rose bouquet combin red rose deep red berri eleg realli want recommend dozen long stem fanci rose even spectacular',
#  b'mine work seem start stick made imposs pump anymor tri soak entir mechan sever time soap water still doesnt work init like click featur sleeker design model gone back use old version sinc one stop work',
#  b'order twice disappoint lobster salad enough mayo hold togeth spice use delici amount meat incred plan order mani time',
#  b'love hot food hot sauc sinc quit young found blair death sauc rang recent firsli must say found death sudden death tast much alik mega death far away best sauc first one hit great tast realli tast habanero chile someth sauc plus slight sweet side hit heat say hit heat first thing notic sauc though much hotter sauc sneak would use five drop big staek like lot heat tri one drop time best supper hot sauc yet tri',
#  b'medium roast arabica dark roast seem ad robusta better european coffe cart noir instanc avail bought amazon review indic target avail random may tri brand pod also avail senseo maxwel home coffe folger',
#  b'red black german raspberri definit one favorit candi clear chewi gelatin center coat crunchi red black sugar sphere theyr sweet tast slight flavor berri repres black one bit less sweet red bare notic hint bitter',
#  b'ill never eat microwav popcorn quick delici look tast like movi theater popcorn better hard believ true',
#  b'chanc tri chocol holland bought wasnt sure sale person couldnt communic past english word well home want final found decent price kind instead mix box sure would fine want like almond hazelnut buy better anyth godiva say lot',
#  b'german sweet licoric noth like flavor licoric root anis oil dark delici haribo german maker gummi make fine licoric wheel unrol licoric long whip els bite wheel like cake prone play candi blow bubbl gum either way excel licoric real treat',
#  b'glorious chees chang life better mutton purifi water lake minatonka locat centuri cave south jerez perfect glass delici buttonwood farm wineri savignon blanc perfect jacuzzi chees humboldt fog attract opposit sex vigor vital tres mangnifiqu',
#  b'switch dark roast medium roast think make great cup coffe defin easiest system use realli make cleanup snap',
#  b'nerd rope absolut delici want cover nerd rope swim pool becom diabet definit one favorit candi',
#  b'place order day ago track show travel around unit state state amazon say order money debit check account plan repeat negat review long take',
#  b'java podz coffe pad fit well senseo coffe maker one pad fit two cup holder make weak cup coffe order larg suppli probabl throw',
#  b'got parm wow much better get store see fast buy guy',
#  b'first doesnt look like photo rose even smaller scrawnier person bad shape arriv',
#  b'surpris find wasabi peanut low price receiv know certain clear sinus qualiti poor would best describ one part tini stale peanut four part crunchi wasabi coat dump one pound bag learn pay littl get less higher qualiti tin posit note vendor prompt ship product probabl good one',
#  b'type chees igourmet excel one big favorit realli differ smelli weird everybodi tri love cracker beer glass white wine right tangi chive onion real treat difficult find store want around hous snack parti',
#  b'good coffe flavor bare detect even cannot pin hazelnut subtl blend like fine perfum bewar brand claim senseo youll get tast get foam layer one definit favorit',
#  b'tri coffe pod senseo singl cup coffe maker keep go back senseo love consist tast coffe',
#  b'best dark chocol youll ever find need eat small piec fulfil chocol crave goe well coffe near anyth els well worth money chocol enjoy',
#  b'beauti aromat fine tea redol delic scent orang spice aroma absolut heaven enough make one feel good tea simpli delici light flavor one may sip without milk one enjoy tea bag strong enough make two delight cup tea constant comment undoubt favorit tea wonder popular moreov tea bag individu foil wrap make especi conveni one may simpli grab one two foil wrap tea bag slip one purs backpack pocket take work refresh afternoon cup one favorit tea',
#  b'like home forget molass pancak syrup sad cannot find san francisco',
#  b'good earli give final rate tri bean',
#  b'fruit slice came hot weather instead coat suger soft gummi',
#  b'ive tri flavor powder chai rate low compar elephan chai flavor rich would buy product',
#  b'tart shell one favorit shell sturdi doesnt break easili sweet butteri textur tast melt mouth sensat',
#  b'bonni countri classic fabul peach corn salsa howev absolut best ever tast make want eat jar spoon',
#  b'serious stuff addict famili argu run way would finish last milk flavor hard descib inspir certain fanatic peopl ive never heard anybodi wasnt impress tri sesam miso stronger spicier flavor light realli improv mild lettuc like iceberg anoth advantag littl goe long way isnt healthiest dress high salt gram fat per tablespoon hand cholesterol free preserv ad figur sinc enjoy salad wouldnt touch good trade realli tast amaz',
#  b'yellow lab puppi looov chew point abl destruct bone older dog friend love mad good materi great shape wonder toy',
#  b'like strong dark roast coffe fill bill nice much better dark roast senseo product need care center pod singl pod holder tap bit otherwis final product bit wateri difficult need pay littl attent insert pod never tri make cup sequenti previous review surpris second cup pod weaker fair logic strongest coffe would cup made fresh ground like regular drip coffe maker make singl cup cup time qualiti good best pod opinion kona coffe pod also avail amazon howev one good everyday altern fan dark roast coffe sinc quit bit less pricey kona pod',
#  b'actual work well carpet well cat love bat around lightweight bop fli everywher chase cheap durabl step chanc cat still love entertain cat toy',
#  b'tea year ago live nyc thought ever sinc unabl find search web call specialti tea shop etc happi find aroma tea beyond compar vanilla chocol subtl mint warm trigger someth brain find way relax put smile face tast equal good illeg worth tri sure',
#  b'best hot chocol first tri california hope one day could find local market excit find amazon get ship gift husband',
#  b'receiv christma gift initi fun go box reliv childhood memori candi evok hit stale candi anoth noth wors bite stale candi unless knowledg someon paid premium there less worth candi box littl retro hard candi wrote compani respons essenti gee that bad advis put candi microwav freshen solut fault sum candi good realli bad youll never know mouth wouldnt buy compani dont stand behind product',
#  b'love salmon spread buy thought would better alaska order item return alaska best salmon salmon spread order item hope would fantast alaska known salmon disappoint tast smell like cat food write compani yet receiv respons',
#  b'appreci calient must tri',
#  b'use love bagel crisp consist tasti good textur someth chang wors longer shape like bagel isnt big deal last bag bought least burn uneven season like tast salti burn toast mean buy bagel crisp',
#  b'found link tofu shirataki articl msn com talk food stay away cours werent talk stay away tofu shirataki noodl steer clear pasta even whole wheat claim glorifi junk food quick turn sugar digest italian avid pasta fan quick googl found link amazon com www com order packag noodl eat health food awhil despit poor review readi give shot glad like tough spaghetti tough mean tire rubber like cook doesnt bother cook marinara sauc put broth made asian style soup serv teriyaki chicken thing versatil fabul weight watcher entir bag noodl point calori gram fiber cant ask better altern pasta expir date month order dont gobbl immedi also make stock conveni stock indefinit complaint ship kinda high guess cold pack stay fresh',
#  b'love facial cleanser skin tend oili flaki longer shini ive break out sinc start use take makeup without leav skin feel tight dri even skin tone even face hasnt look good sinc day love never use anyth els',
#  b'although understand goreng part name mean noodl without broth ill never stop call ramen mean noodl broth indomi product ive tri origin satay peda delici make mistak orient noodl local asian market ran indomi owner told get differ brand promis like better end throw tast aw indomi origin howev mellow tast enough spice keep interest noodl done classic',
#  b'magnesium vital import mani level help muscl relax also aid sleep allow calm balanc state mind low level miner make near everi diseas wors whether deal asthma diabet depress cardiovascular diseas assist assimul calcium potassium osteoporosi concern look includ magnesium supplement use magnesium calm past year found help relax muscl tension get good night sleep mention calm effect state mind easi take come sever flavor well recommend mani massag client decreas pain discomfort bodi',
#  b'still havent gotten product gristed forc use expedit ship cost flat whop would suggest would get order fast wrong two week noth tri contact figur get cannot access order right gyp order like bewar ship hope actual get deliveri',
#  b'great organ chocol great organ chocol even good even fair organ chocol extrem poor chocol chalki smooth flavor absolut horrend expect hint ginger chai bar overpow hint flavor complet wash chocol flavor surpris nasti bar refus call chocol spit threw bar yuck',
#  b'plain flavor soy milk great tri particular ad nutrient cereal morn delici cold drink great shake',
#  b'bit nutti clever market sauc pretti crappi given chunki consist fact word colon name pretti much turn appear result colon cleans ask case odd slight bitter tast think mustard put yuck',
#  b'love cycl love long distanc alway hate way gatorad powerad ect tast tast sweet salti unless extrem dehydr alway prefer water cytomax exact say cut burn defin help even peform longer workout best tast pretti good complaint tast love boost perform receiv',
#  b'receiv month ice cream club gift disappoint ice cream receiv giver unhappi see choic sent month first month includ duplic black walnut bland vanilla frozen yogurt type caramel didnt tast like caramel tri couldnt give away also peppermint one month email month complaint think might want take second look sent receiv immedi respons apolog offer extra month ice cream also told spoke shipper told month realli go scrumptous receiv may somewhat better one pint higher butterfat averag groceri store brand frozen custard neopolitan excit squar cardboard carton compani even mention number ice cream store citi thus far receiv pint month might compar felt write review person sent gift review read idea might receiv duplic along vanilla custard neopolitan',
#  b'content peanut salt still natur even afford everyday consumpt increas palat mean peopl eat good stuff fussi eat kid like mine peanut star unsalt get star couldnt much simpler natur element salt best peanut butter noth ad realli big deal nation brand offer peanut butter product contain much ingredi peanut much ingredi natur rather chemic synthet addit preserv fat emulsifi salt sugar best thing ad wow probabl signific noth ad absenc hydrogen make thing like margarin lard even wors human consumpt alreadi would ad summer heat may increas need salt small amount salt per serv gram entir jar probabl good thing must peopl consum especi summer electrolit loss issu bear mind daili rda salt gram bottom smucker next best thing certifi organ whatev benefit peanut may offer best way get benefit eat nut secur certifi organ product cours prohibit expens diet tri ad product affili product',
#  b'dont give inform find spammer list work spammer',
#  b'first diagnos ib bought tea sooth digest contain fennel peppermint three ingredi known help discomfort caus ib tasti wasnt help symptom diagnos ib may possibl also like pleas awar tea contain barley malt list product descript danger celiac',
#  b'item came fast well packag describ would total busi thank alot',
#  b'put one mouth youll understand theyr bad bad theyr baddest baddest black hole tast want say theyr realli forget',
#  b'ever seen heart worm vet offic well couldnt get past look noodl packag eat defini could get past textur like choke worm ever imagin like realli disappoint noodl hope go one key weight watch success',
#  b'rate product star never abl tri up put packag mark perish patio apart sinc winter dont note left apart door reason found neighbor notic told spoil feel either deserv refund redeliveri product cost expect prompt resolut problem rebecca robin',
#  b'happi product quit unhappi ship charg purchas bought local',
#  b'like noodl got problem took month half get product accept pay ship pay much get noodl expect week problem depart',
#  b'nine cat crazi kibbl last thing want cat food cat hate ill buy',
#  b'thought buy coffe maker would convient mother realiz hard get disk everyon shop line especi age live anoth state rural area hard find disk also never abl find maxwel hous disk',
#  b'much product thought would give tri order onlin pay like ship small bag realli excit tri gross isnt much tast textur horribl stringi strechi big disappoint threw second bag',
#  b'enjoy use philip senseo coffe maker year coffe drinker famili abl brew one cup time conveinc ive tri brand coffe pod senseo machin douw egbert pod produc best cup coffe full rich smooth flavor nice head foam never tart bitter pefer dark roast keep medium mild roast hand guest',
#  b'earl grey favorit blend tea far competit biggest secret tea given earl grey hoswick hall british prime minist chines manadarin report gratitud earl save life get right doseag bergamot oil rather intens tangi scent deriv bergamot orang turn cross pear lemon sour latter nativ south vietnam oil probabl recip origin ingredi use much bergamot oil easili obscur black tea natur flavor twine cant wrong origin earl grey turn compani match quick dwindl suppli receiv chines friend twine mandarin tasti gift began run earl grey ask tea merchant twine match twine uniqu blend grey famili favourit guest inquir direct twine strand would ask earl grey tea name unless insist tea cream milk recommend one without kind milk origin recip call mind plain ruin blend particular flavor that cours whichev way though scent tea kind thing twine earl grey right alley care oversteep except forgiv tea like exampl yunnan turn flat bitter decent earl grey minut plenti steep time twine certain',
#  b'green plus chocol energi bar tast great fill dont bounc blood sugar shake hungri hour love',
#  b'amaz easi fix tofu shirataki noodl great tast consum normal enjoy tofu product noodl great low calori tran fat gram carb noodl amaz product',
#  b'box seem item differ say right substitut pictur box what go',
#  b'recent got kitten discov somewhat finnicki thought afraid tri feed regular treat meow mix fish discov didnt like bought impuls werent much buy scratch post wow respons got impress also made cat resist hes tri bite tin sever time say impress',
#  b'order item along regular noodl never got made million attempt success charg alreadi paid item ship gristed probabl never order amazon gotten satisfact last email sent never even answer',
#  b'best sport bar around great tast organ contain plenti antioxid contain good amount protein side high amount carb especi sugar still give five star',
#  b'like one bit medium roast robust great good enough',
#  b'littl hesit instruct cook mix first open didnt think would readi time gave minut boil remov pot burner leav cover hour ad mixtur chicken fish pleasant surpris lift lid pot saw jambalaya readi eat definit order mix word caution mix littl spici love spici food wasnt problem peopl may find littl hot tast',
#  b'coffe maker work fine impress tast coffe tast much like instant',
#  b'first tast tea plan alway hand home love',
#  b'best lunch minut eat desk fresh sauc tast good vegetarian yum',
#  b'love tast filll offic wonder aroma',
#  b'quit textur pasta still good sinc pasta flavor anyway took flavor sauc tast would recommend anyon want heavi pasta',
#  b'drink green tea year love tast smell open box tea thought stand old ash tray smell horrid doesnt infus well water steep tabl spoon five minut water color bare chang high recommend buy tea exot product asid plain old lipton green tea bag groceri store far better',
#  b'start run coupl year ago ran first marathon last year alway carri powergel long run yes powergel sugar caffin bonk mile mile run super glad one pocket think benefit come main sugar tend buy flavor caffin general give powergel star give tangerin flavor two star didnt like tast flavor much better',
#  b'order product januari april still havent receiv leav compani alon dont buy suck disgruntl',
#  b'year use boboli pizza crust enjoy much taken market period time month ago put back shelv sinc total tasteless noth like use dont know previous problem probabl purchas last boboli pizza crust ask rate product feel even qualifi pleas bring back previous recip explain reason chang',
#  b'friend sent mst last fall sinc order countless bag share friend famili drink almost everi day robust tast like typic concoct usual tea drinker convert stuff great',
#  b'bought girlfriend eat gluten kept one bag self caus make good pancak first made crepe light yummi put fresh fruit chocol yum next day made pancak waffl sooooo good dont eat pancak doubt back usual mix mix also use bake applic buy case',
#  b'get good number treat even thought still pricey soft quit pretti squish though treat soft enough could like mold around pill need suppos cat gobbl empti one second eager gobbl one pill well soon bit discov pill onto floor went like treat enough lick treat bit though leav soggi pill behind anoth empti ate slight hesit wonder next pill actual went way suppos yay thought struggl pill next time though bit treat found pill fact hed deliber nibbl uncov pill tri start refus treat even without pill fact hed gotten distrust quick hidden pill trick even distrust soft treat sever day resort crunchi one reward swallow pill bad seem chew food rather bolt hide pill food never work either think didnt chew might work better resort routin get fed pick carri particular chair get sat reciev pill pill goe hes reward treat soon pill goe sever time routin doesnt come run settl stop struggl run away right rather look eager say where treat suppos get treat know least pill pocket use much rate',
#  b'tast like someon left cereal box open tooo long stale side though smell great bad purchas bag enjoy banana granola though excel',
#  b'vegan tri everi tofu product market noth ever came close terribl textur noodl smell open bag pleasant wash parboil goe away replac slight sweet smell dislik almost much kept open mind cook noodl minut ad favorit sauc fresh ground pepper soy chees grate top whoever said like eat rubber band exact target incred chewi dont tast great either even low calori food seem like wast spend calori noodl',
#  b'bought mother day gift coffe lover found came one pound regular one pound decaf three pound regular substitut cracker smash cappuccino liquer cake open day gift wrap realli dissapoint decaf coffe addict turn realli expens pound coffe nice basket',
#  b'best check local asian food market japans anim store price usual better consid wont stuck someth end hate also lot varieti pocki what sold there even giant pocki custard pocki green tea etc alway new one come market internet store compar price mayb wise choic curious snacker bewar though even didnt like sesam fyi men pocki bitter instead milk chocol best flavor opinion novic pocki snacker like men strawberri without extra bit almond crush',
#  b'wife son gluten allergi gluten free bread quit dens dri pamela amaz bread moist light fluffi wheat eater love bread far beast gluten free bread mix ever tri',
#  b'two golden retriev chew way treat time anymor everlast treat toy one side hold treat last kid go week love tast teeth look great continu play right get last bit treat packag say dog busi hour arent lie sold product busi stock refil keep golden happi',
#  b'tea reciv woodi stuff littl stick green stuff ship near price tea end pay pound yerba mate reciev order got smart googl yerba mate found lot site offer lot tea lot less money like instead paid also site offer genuin argentinean brand think ill tri next',
#  b'last time check water base product poop arent realli frozen degre person tri catch poop bag take straight deep freez prevent freezer burn white crusti layer',
#  b'problem eat bar tast thought wow nice addit raw diet howev hour later stomach got real queasi threw sever time great experi return bar howev postag fee etc refund dollar total order buyer bewar',
#  b'stumbl three dog bakeri vanilla woofer target five year ago buy ever sinc reason target stop carri still order onlin dog love thing especi vanilla peanut woofer yet tri alway fresh last quit disappoint either also love support graci foundat',
#  b'order event still receiv product supplier respond email inquiri deliveri',
#  b'made without hydrogen oil good thing sinc difficult bodi absorb acid come hydrogen oil definit natur snack cracker bounc around mean rare find even natur food without hydrogen oil cant count time ive read label disappoint find natur alway mean healthi certifi organ wheat flour expel press safflow oil age cheddar chees contain milk salt enzym chees cultur salt yeast extract paprika annatto extract color ground celeri seed onion powder yeast ive made chees cracker realli tast homemad tini cracker satisfi chees cracker crave calori cracker berni bunni anni belov mascot approv also made vegetarian ingredi love cute rabbit shape add cracker snack mix pumpkin seed chocol chip dri cranberri genisoy soy nut anyth els think includ sunflow seed rebecca review',
#  b'would first applaud product good unfortun would rather give drink drink tasteless slop nasti artifici acrid citrusi time sweet tast product strawberri margherita mix faint tast strawberri amount doctor could make drinkabl pour mix mai tai mix pour bought sever bottl dri drink mix varieti without tri first big mistak either go pour throw sinc folk baja bob web site refus even respond request return unopen product refund also note web site fan club page entri save money unless total desper youd better use crystal light rubi red grapefruit tast pretti good mix vodka',
#  b'well kit tri first back row plant center front best basil shoot right pod dill cilantro grow tall lot mint tini chive loop back spong yet tri stand straight oregano sprout within spong yet come hide begin week believ could probabl harvest littl basil end week big question parsley peopl suggest substitut parsley oregano rather replac red rubin basil recip oregano none specif call purpl basil howev never tast stuff may chang mind hope includ becas tast look easi low mainten kit refil water bowl water get low add nutrient tablet everi week come starter nutrient sprout nutrient regular nutrient tablet ask place pod order came box possibl slight variabl light level light hour water light set parsley part italian french herb kit avail septemb',
#  b'wow eat your fine eat half hand youll pop hour eat hand better stay near bathroom rest day tast great like regular one theyll affect way one',
#  b'struggl year half give cat daili pill foam vomit easili dread daili tortur tri buri pill everi treat delici food could think includ raw liver soon smell pill disgust bitter tast vet say wouldnt tri anyth week tri pill pocket cat stood head get hand could eat goe absolut nut doesnt detect pill worst part cat day worst part day great recommend stuff high week cat decid longer like chicken flavor continu eat salmon flavor one sometim wont eat unless wrap small cat treat like sandwich dont need use entir pill pocket small pill pinch need bag last long longer usual',
#  b'dri bing cherri sweet want dri cherri make good snack packag bulk packag perfect full warn sulfur dri cherri expect eggi reaction',
#  b'nut healthi numer benefit besid energi sourc brand particular delici littl salti pecan greatest overal kind nut abund tast good',
#  b'half usual retail price get top qualiti breakfast blend avail good price reason quaniti that get cute littl tin box easili convert piggi bank treasur chest use straight also blend tea dont overdo tea pack respect caffein punch best plenti milk sugar start engin',
#  b'one best season ive ever user particulari grill meat scarc avail cut call sprinkl liber side meat refriger overnight grill high heat side minut depend thick desir finish',
#  b'pretti interest arent good bought road trip land hotel one night fast food place close ate left food two packag daughter gfcf open spit sister ate gag hungri pretzel crunch tast mayb salt flavor wouldnt',
#  b'youv ever eaten real meat current meat eater tri veggi product put asid stuff doesnt tast like chicken forgiv isnt chicken tast like cross cardboard box dog food sort brownish color terribl textur like cook chicken there bit cook someon sculpt patti coat fri mine aw none could eat end go dinner',
#  b'tast great that find local buy cheaper store',
#  b'dont afraid tri sauc sweet tangi mildest mild sauc tri wing youll never want sauc good',
#  b'cannot rate product open jar problem negoti amazon purchas although tri get sent anoth address along sever item end come instead ship killer want warn read email amazon send care thing may happen next time ship someth address next time buy direct merchant instead go amazon ship killer star amazon ship page',
#  b'mani unsual type cola drink enjoy dont like certain drink least abl sampl decid dont particular like case chinotto drink tast aw sort made gag littl tri second tast best decrib would like drink liquid vegemit never brought vegemit later life abl pick truli enjoy tast would recommend give shot store pop one open quick sip leav shelf run away quick advanc palat',
#  b'stop buy kraft mac chees got start anni product kid love arthur thought pretti cool arthur shape mac chees arthur head buster arthur fave chees sauc tast like real chees sweet overprocess kraft sauc acquir tast anni there go back hand kid friend come lunch often turn nose anni mac chees accustom kraft like like anni main tast keep come back',
#  b'pretti tasti bar wife eat candi bar dessert ive tri genisoy flavor far favorit wife think tie chocol mint peanut butter thing keep give fifth star price bad market still wish bit less',
#  b'first time drank tea couldnt believ flavor even without sugar tart difficult find store',
#  b'daughter allerg milk egg nut find good snack food kiddi eat problemat simpli love veggi booti open bag throw tabl get way fast dont lose hand three kid age month year demolish bag quit easili one sit obvious dont worri go stale',
#  b'excit find sale amazon reason price tri first time day ago wish nearbi store carri everyon ive given like even normal healthi eater crisp reminisc puffi corn snack like cheeto differ light flavor calori content similar snack per serv nutrit benefit per serv calcium per serv iron per serv havent tri ceasar flavor yet intend near futur',
#  b'buy divina oliv spread larg quantiti opinion best blend oliv spread ive tri lot differ brand divina far best wont disappoint littl pricey worth',
#  b'pretzel suppos salti tad salti also burnt flavor could say distinct smokey flavor bag ahead prospect unsatisfi pallett mighti tall order hand subtl sweet flavor good ordinari pretzel tri safeti first instead buy bag also note groceri item cannot return amazon',
#  b'buy crunchi product hot summer month heat sensit packag state store cool dri area two case purchas arriv chewi clump togeth probabl cook ship raw food nutriti anymor two bag bit powder fruit clump chuck fruit one open amazon com accept groceri return wast',
#  b'pretti good inexpens steak sauc effect marinad signific acid content typic vinegar order tender break meat mix doesnt qualifi leav steak float stuff day tast grill let soak minut fork',
#  b'texa pete worst first made north carolina serv diner carolina like ketchup complement well doesnt add heat rate scovill unit texa pete describ hot sauc flavor tomato sauc dont way find stuff aint worth',
#  b'huge fan tea tasti keep awak long hour work front comput screen mmmm tea',
#  b'think mix tast good prepar quick liptun cajun rice bean',
#  b'longer find product local found line reason price quick shipment buy',
#  b'right size snack pack old healthier altern packag cracker without sacrif tast',
#  b'desper tri find someth replac creamer grown accustom morn cup coffe cant drink coffe without ad sweeten came across product put one tablespoon dash cinnamon coffe good easili calori less per cup previous drink',
#  b'reason product flavor ad pepper lack flavor resembl stroganoff way would get star option',
#  b'love use bread machin want reliabl yeast need proof cant rememb last time yeast make life much easier rapid yeast bread seem rise quick packet yeast groceri store save time give empow feel instead go rise feel yeast store refriger freezer conveni use unlik yeast cake dont worri mix water milk measur bread machin recip love make focaccia bread turn wonder start bread machin make hand serv slice squar top butter fresh rosemari herb cream chees perfect homemad soup winter focaccia bread machin start machin finish hand cup water tablespoon saf instant yeast tablespoon sugar teaspoon fresh crush sea salt tablespoon oliv oil cup flour baker catalogu sell amaz flour measur water yeast sugar salt oliv oil flour bread pan program white bread dough cycl larg loaf dough knead put larg stainless bowl cover dough damp cloth normal forget catch rise top pan still work either way could also use half ingredi one loaf want let rise bread machin pan let rise doubl warm place secret turn oven almost immedi leav feel heat hand seem creat warm enough environ bread rise punch divid third roll two squar one elong loaf work well regular size cooki sheet larger cooki sheet roll dough two squar make deep indent end roll pin handl regular interv brush oliv oil let bread rise almost doubl either sprinkl sea salt sprinkl dri fresh rosemari sea salt also top dough tomato slice onion slice slice pit kalamata oliv bake bake degre minut bread cool slice easili freez well normal slice two loav cut one squar sandwich make herb cream blend togeth cup butter packag cream chees teaspoon dri parsley teaspoon dri rosemari teaspoon dri thyme idea bread came visit sandwich shop garden center seattl arriv home visit grandmoth knew tri make cream chees bread perfect serv homemad soup bread lot possibl vari top suit type soup serv instant yeast alway work bread machin end feel like profession baker result sure impress bread alway fresh bakeri tast unlik tast bread made packet yeast rebecca review',
#  b'bought think give tri mayb cut diet snappl ive buy costco made today realli cant tell differ there aftertast pick realli peach flavor bitter tea sometim use teaspoon snappl glass bottl authent feel also handi realli tast look littl darker that fine happi purchas given money ill save',
#  b'happi find pepperidg farm stuf ship fast open box discov packag stale date expir month ago yes doubl check date threw trash',
#  b'good roast seawe excel fact compani dri seawe let tell lazi realli dont know seawe see that problem world today lazi rememb time compani peopl care go extra mile qualiti still matter shame everyon speed conveni speed conveni like treadmil realli fast escal someth quick autom like dont know wrong everyon sometim sit shake head roast make seawe almost tast like chicken use favourit recip think youv die gone heaven yamamotoyama best',
#  b'order box regular hone box well got regular hone fine milk one came week later got anoth box regular one mistak awfulthey werent store right chewey honey crystal',
#  b'like nut your look healthi great tast snack cant wrong almond crunch husband recent elimin high fructos corn syrup partial hydrogen soybean oil diet feel much better tri find tasti snack dont contain product easi thrill find mrs may natur love cashew crunch well',
#  b'found pietro dress food show year ago annoy couldnt find store thank amazon avail line deliv door here first got hook demonstr bowl lettuc put two piec cut lettuc small cup ad two drop dress top tast heaven high fat content that bad secret use littl dont pour flavor intens tast immedi favorit flavor offer miso ginger come next even pickl plum interest compani ship fast custom servic conveni order line dont need search thank god internet steve',
#  b'found pietro dress food show year ago annoy couldnt find store thank amazon avail line deliv door here first got hook demonstr bowl lettuc put two piec cut lettuc small cup ad two drop dress top tast heaven high fat content that bad secret use littl dont pour flavor intens tast immedi one favorit flavor offer shoyu favorit even pickl plum interest compani ship fast custom servic conveni order line dont need search thank god internet steve',
#  b'tasti especi blueberri bit prici compar thing like whole food upscal store order road trip van fresh fruit may limit',
#  b'well love mrs dash product differ tri most product make food tast good',
#  b'dont know mess coconut chocol amount fat calori babi tast lot better your realli look delici raw food bar prefer larabar',
#  b'love light zesti italian extra virgin oliv oil flavor realli much tast kraft fat free zesti italian light dress definit zesti feel couldnt even tell differ regular salad dress way kraft',
#  b'test cooki recip got similar result use black treacl unsulphur molass',
#  b'best thing sinc slice bread wonder luck pill give sinc start use small size cover smaller capsul dog love tast guy jump scrambl get amaz product dog extrem ill noth entic eat even pill pocket per cent time work',
#  b'like make sweet tea gallon tri limit amount sugar use grain necta sweet saccharin sugar conveni put tablet gallon jug add touch sugar pour steep tea water fill jug quick delici',
#  b'could easier enjoy refri bean put mexican meal togeth spur moment santa fes refri bean easi prepar side dish answer faster cook can bean prefer tast consist can product enjoy',
#  b'ive bought gum sever time good tast littl aftertast noth bad gave two star didnt feel like coffe high doesnt even come close coffe tast good though cant hurt tri review gum anyway bore',
#  b'pod type coffe take guess work make morn cup ojo coffe smooth great frothi head wish offer espresso pod buz',
#  b'order vanilla bean wait arriv final wrote review didnt come time receiv note java guy replac order quick honest bean beauti woul like recip bean java guy send coupl suggest use bean bean smell like vanilla though anoth bean smell vanilla thank much quick repli complaint wanda',
#  b'newman organ alphabet cooki chocolatey crunchi first time tri hook two children also think fantast tri organ cooki cooki good start point',
#  b'pound cat solid month kept strict diet amount recommend size actual reduc bit measur measur cup daili didnt even lose ounc',
#  b'tast bad return use one pkgs cant return wont buy bulk pleas call',
#  b'second flavor last outsid strawberri flavor gum mix lime liquid center pretti enjoy downhil sinc chew fruit strip gum child rememb gum lose flavor quick mayb get minut flavor like chew rubber packag anoth annoy foil blister pack cardboard sleev contain nine piec gum wast packag consid whole thing could put packag made mistak buy pack must singl pack enough turn',
#  b'receiv jar instant espresso gift quit insult first ive never use instant coffe kind couldnt figur gave past weekend coffe bean must coffe morn made wow awesom fact drink mug right right review love howev make latt fashion ive also ad hot chocol mocha latt ill definit look neighborhood store cant find ill get amazon definit great buy',
#  b'gastric bypass surgeri eat gram protein everi day protein shake give like get sourc also small cup stomach cant wast space snack cant benefit vitamin protein nutrient valu also cant eat sugar eat sugar substitut kay natur product great ton protein tast great cinnamon toast pretzel stick great sweeten low enough ingredi list abl toler isnt much white cheddar kruncheez snack great also like cheeto like abl snack peopl also thank kay help take casr enjoy food make eat littl normal lisa',
#  b'think pretti good pop wouldnt tri compar mix plain water fresh pink lemonad stuff unfortun dilut much get bitter acid excess water caus extra ionize citric acid lower consider make spring water per packag youll love except want homemad lemonad',
#  b'packag contain fresh peanut cashew packag fill fresh nut noth salt ad peanut oil cottonse snack food healthi choic although expens ounc ounc basi portion snack food still fair valu relat healthi choic bear mind calori per ounc fat acid cholesterol healthi oil big complaint mani product lack fresh fact rancid tast nut never happen planter nut fact individu packag expir date clear mark front packag bottom prefer larger jar eat time prefer get peanut cashew larger jar unsalt summer salt okay fresh consist everi packag product info kraft websit affili product',
#  b'stay away great american spice compani dont answer number local number email investig state attorney general ship item settl dont care custom ask buy',
#  b'mix heap spoon oat bran glass orang juic everi morn reduc cholesterol well less less year ldl bad drop hdl good almost remain level cant possibl ask anyth better use bit oat bran everyday amaz stuff',
#  b'freez dri fruit expens sinc mani fruit water strawberri except littl contain made lbs fruit flavor concentr price peopl couldnt lbs strawberri minut down littl treat someth els look healthi candi altern contain vitamin materi fiber nutrient strawcerri also sugar calori lbs fruit theyr aw yummi tri get addict',
#  b'love nana cooki bar cooki thought give tri even though gluten made rice flour instead wheat flour look nice textur bit strang kind like eat realli fine sand dri crumbl slightest touch dont tast bad plus wont buy',
#  b'love black licoric differ tast good way salti like anchovi fact seem bit fishi',
#  b'order stuff veganessenti year ago psych vegan jerki blech tast like oversp cardboard didnt anyth common meat jerki recommend primal strip brand right tast textur beef jerki',
#  b'ever sinc start use caff kimbo espresso napolitano stop go starbuck man differ beyond compar purchas espresso machin sure pay caff kimbo tast aroma superior coff around claim best want real italian caff experi golden crema see tast must tri caff kimbo espresso napolitano',
#  b'indian american friend get free whole powder egg gov commod program often made yummi flavorful egg sandwich scrambl egg decid buy honeyvill tri disappoint scrambl egg dont know bake flavor whatsoev stick hard oil stainless fri pan fri like pancak med low work better mix canola oil per egg like waffl egg mix cup water cup mix say runni mess mayb bake limit shelf life store unus mix freezer',
#  b'disgust tender beef jerki that oxymoron papaya tender destroy tough come love crave beef jerki textur doggi treat thank',
#  b'flavigni town think film chocolat ancient candi factori make kind pastill hard candi violet pastill round candi white deepli scent violet extract anis seed center great sweet breath tast acquir addict',
#  b'tast wonder toss bob red mill date piec fig dri appl someth similiar english pud dens moist rich wish came larger packag three crowd eat time dont tell relat upfront whole wheat natur ingredi convinc anyth advertis tast terribl',
#  b'agre everyth previous review wrote review gave cooki rate star though havent eaten cooki year without get sick sever allergi wheat soy pretti much everi cooki find normal groceri store one ingredi found nana cooki happi yes textur differ wheat cooki better go without cooki also doesnt hurt cooki delici like limit diet cooki welcom addit diet',
#  b'drink cup right start drink visit friend ireland main didnt coffe soon crave brought home box flew back search web found got nice mellow flavor suspect got pretti high caffien content compar sweet tea normal drink cold georgia feel like ive coffe cup drink littl milk sugar great year later persist belief best tea worth special order got tetley british blend local store blind tast test turn cant tell differ still like lyon fine dont think ill special order also learn snob',
#  b'think amazon right track offer groceri think need stick major brand work bit make price competit still quit bit safeway mention expect pay littl conveni quit much rice crispi littl differ expect dont quit understand make buy quantiti packag pre packag expect get four box somehow stuck togeth band togeth eas ship cost quit surpris get cereal one two box cereal ship box go ship wouldnt better let buy smaller quantiti increas overal sale',
#  b'obvious look review peopl think stuff either realli good realli bad think accord tast expect price order packet two differ web site tast like frosti rich shake order drive thru window wouldnt pay price found recip serendip restaur make frozen hot chocol ad tini bit real chocol bit milk cocoa ice blender feel recip tast much like oprah said good equival restaur actual serv want expens milkshak would tri recip use real chocol stay away drive thru milkshak mix',
#  b'yet tri coffe flavor say bit coffe snob time dark roast best cup coffe ive home locat ever love dark coffe never get tast quit right drink black perfect go tri anoth flavor love better stock seem bit pricey good cup coffe quick stuff best',
#  b'tast realli good your fan chocol raspberri tri raspberri sweet glossi goopi even tast seed think add authent chocol good cooki plus lower fat would think two littl chocol raspberri cooki would wish cooki pretti one box though',
# ...
#  b'order marzipan last christma amaz great deal found unfortun old addag get pay marzipan made corn syrup instead sugar low almond content flavor hint citrus mask almond flavor whatsoev may well eat glue stick even interest froze unus marzipan bag better varieti within three month marzipan taken freezer tast wherea higher grade marzipan still tast great even one year later bag togeth ingredi didnt hold never buy cheap marzipan thrown bulk marzipan purchas compani',
#  b'kashi special smart start deceiv',
#  b'pug favorit toy chew bone end hour time remov gnawhid treat right away dont realli care nylon end favorit part',
#  b'order marzipan last christma amaz great deal found unfortun old addag get pay marzipan made corn syrup instead sugar doesnt textur even interest froze unus marzipan bag better varieti within three month marzipan taken freezer tast wherea higher grade marzipan still tast great even one year later bag togeth ingredi didnt hold may fine gourmand refin palat go recogn differ right away glad didnt buy ten pound block like origin intend may suitabl marzipan doesnt take center stage marzipan flavor import pay extra money almond past made sugar',
#  b'german chocol tickl buy everi xmas smooth rich eleg arriv day thank',
#  b'best mani small piec enough full popcorn enjoy',
#  b'yum yum tri product base upon mani posit review creat wonder delici moist somewhat dens chewi loaf bread machin much much better store bought loav weve tri satifi even kid sensori issu purchas anoth case today pancak mix wonder',
#  b'price saffron valencia spain retail palm beach gourmet market dec',
#  b'someth wrong peach purchas sun maid dri peach groceri store walmart past wonder absolut foul tast also notic dri peach longer shown one sun maid product sun maid web site also longer find local groceri store note amazon accept return food product high recommend buy',
#  b'ive drink tea year wonder tast jasmin old like might remind flavor old wax coke bottl juic may sound pleasant ever know mean mild sweet sweeten littl splenda stevia enjoy',
#  b'chip good end eat whole bag day caus good glad dextros like lay',
#  b'order onlin ship flimsi box groceri store use addit packag use protect insid box crush three corner ad alreadi crush chip wound feed bird',
#  b'dri cherri good get anyon would give less star rate amaz theyr much better raisin oatmeal liven tapioca pud delici cooki chocol chip cooki made ghirardelli dark chocol chip fresh pecan cours dri cherri tri youll like',
#  b'schnauzer love treat theyr healthi great train also love peanut butter flavor high recommend',
#  b'order two grand basket although arriv within day one basket completey destroy compani see could reship new basket christma week away new basket arriv size first littl select needless say recomend compani buy ever',
#  b'your look adult version raisin bran sure tri flake remain crunchi quit time raisin larger frequent pack full vitamin great great stuff even cat like hey cant beat consum quit bit stuff hous high recommend',
#  b'former english roommat introduc tip whilst univers love tast ive pass tradit sister friend hot tea drinker happen work togeth sinc introduct tip proper tea time work everi day lol thank',
#  b'year ago product coffe shop ran delight find open market still abl purchas often mani custom exclaim product best ever tend agre other good yet find go big train time great keep',
#  b'cant tast green tea ginseng tea bag would recommend lipton honey lemon ginseng someon enjoy green tea ginseng flavor extra boost energi stay away product would buy product',
#  b'savori choic liquid veget broth concentr box pack bought concentr veget chicken turkey flavor couldnt find veget broth local husband need brine cook chef famili skeptic tast richest flavor broth ever reconstitut direct keep full deep color sinc concentr dilut littl much need littl packag conveni well take much less space typic can never go back regular broth',
#  b'love good coffe hunch bought wow great coffe hard use fine coffe left keep want make pot best coffe yet',
#  b'love tea especi ice sweet still tast natur peach flavor relax usual put three teabag litter pitcher serv realli good',
#  b'corn kernel small pop result small pop corn good children pop hot air popper',
#  b'ginger altoid best sweet spici flavor put mouth fire calm cough upset stomach frighten could longer find target specialti food store area howev amazon rescu gotta love amazon absolut delight find amazon groceri lower price pay local pleas amazon never stop sell',
#  b'obvious price right that star right conveni deliveri spare dont even know mani trip niger that anoth star howev tri might could never get stuff enrich fulli work half well ballist missil research reactor itd star mayb youll better luck possibl centrifug hinki',
#  b'dont usual write negat review dont write anyth product bad deserv realli bad review first suppos low carb take stick butter mountain heavi cream make huh low carb heart attack fat yuk second difficult make three differ bag need three bowl lot measur lot utensil lot work would less work creat scratch third creat jelli roll type item creat big gloppi sticki mess difficult work fourth come like came like biscuit scone bake glob fifth tast lousi plain lousi even pecan top tast good dont wast money mess second one dixi low carb item ive made one wors next dont bother',
#  b'littl grain great addit muffin bread pancak alway soak boil water ad recip add delight littl crunch subtl textur bake recip pud recip bag yummi think would great certain cooki next experi sure thought could ad number recip bulk benefit whole grain good also littl bit goe long way christma year use two bag give friend along bob flax seed bran muffin recip call ingredi',
#  b'shar pei realli like chicken beef roll easi break littl piec train major snack seem dri ligament pig skin dog like got tire day think next time order snack individu',
#  b'pay local coffe shop thrill find amazon yummi healthi mind yummi',
#  b'tea isnt bad tast littl bit like hay stuff ive gotten local espresso royal put tea shame could tradit real deal tea wouldnt know tast littl bit',
#  b'purchas item christma gift husband love cheesecak love say one best cheesecak ever would recommend product anyon fresh absolut delici enjoy',
#  b'worst product ever purchas use make pizza crust could even cover half pizza pan tast horribl use make biscuit incred dri flavor tri ad margarin still tast aw tri make pancak batter thick cement tri ad liquid horribl cannot imagin product still market krusteaz use make wonder bake product know done stuff howev aw',
#  b'great popcorn good pop result wonder flavor cant help love run recommend one',
#  b'love cereal saw big sale box bought box halfway first breakfast wife realiz littl black seed look thing cereal actual littl dead bug said start look bowl realiz full big fan cereal never purchas amazon probabl internet matter groceri store fine buyer bewar',
#  b'love idea microwav popcorn without butter simpli salt case littl mislead salti thus high sodium blood pressur issu ill got back tender white varieti good',
#  b'dog chew anyth els sonc gave first time year ago dont mind though sinc know natur know risk give rawhid hes dog everyth get suit size',
#  b'flavorless black filler flavor bare discern licoric tast starchi gel doesnt realli chew first bite candi tube collaps fragment smaller gel bit like made candi someon doesnt like tast bought five lbs wast stupid hope licoric lover dont get burnt good luck',
#  b'use chestnut jar thanksgiv stuf everi year dont time roast peel brand leav lot hard black membran nut still pick brand clean fresh made prepar much easier',
#  b'wish could rate higher pretti tasteless need realli desper muffin eat one light air almost like didnt muffin manufactur need add banana flavour least realli worth high item cost ship cost',
#  b'purchas tomato fruit munchi tub pack fruit mixtur good eat raisin hard almost broke tooth would buy product buy strawberri break teeth excel would suggest compani includ raisin mixtur anymor thank',
#  b'expect fishi tast crab dib lobster didnt care',
#  b'cannot find store live creami delici easi prepar good price arriv fast',
#  b'like spici noodl soup anytim want quick lunch especi nice cold flu symptom say cure anyth least clear sinus',
#  b'healthi reason inexpens healthi snack even kid grab one',
#  b'caff appassionato sumatra ground bag pack got worst sumatra coffe ive ever tast possibl worst coffe ever come coffe maker glad see sumatra coffe avail amazon could subscrib get regular learn drink enjoy coffe extend stay netherland almost year fan world best coffe douw egbert douw egbert ground coffe medium roast ounc igourmet com picki arabica import although web page say arabica hard believ see packag smell label packag mention noth contain arabica bean hard ever write review amazon sooo bad shock despit repeat brew differ strength differ machin differ filter etc noth work bad coffe bitter acid yeccch sumatra coffe arabica bean suppos cut acid bitter acid bitter coffe ive tast know mayb got bad batch amazon polici return allow guess remain pound dispos',
#  b'first foremost toaster pastri tast great get light crusti pastri impress chocol flavor your worri whether toaster pastri bill organ healthi measur favor market leader suggest tri think youll pleasant surpris would definit stretch call toaster pastri health food despit organ low sodium zero tran fat vegetarian claim satur fat percentag usrda calori refer diet relat low toaster pastri percent total calori come fat also relat low much diet damag one two kind cooki portion size pastri nutrit inform provid assum your eat entir pastri far satisfi cooki two mani peopl might find half pastri satisfi your look someth sweet eat call good choic kosher certif provid cor kashrus council canada base toronto ontario product dairi',
#  b'use think lawri best taco season noth compar perfect taco add taco season one pound cook drain ground beef instead ad water add one dice tomato realli cant make taco way',
#  b'appreci abl purchas item case favorit winter beverag',
#  b'best cup coffe ever use dunkin donut fan sinc tri blend brew take road instead pay cup like strong bold coffe flavor without bitter tast one',
#  b'christma bake need apricot turkish mediterranean sweet enough tart real happi found onlin sinc supermarket carri anymor thank',
#  b'cat love spongi foam ball love bite shes roam around hous',
#  b'like bean coffe averag best strong woodi tast aroma would buy',
#  b'one worst thing ever tasi supos drinkabl fizz chemical grand children tast got sick noth like real fizzi old reccogmend suicid hide tast might make throw screw suicid attempt sell larg quantiti tast one one would ever buy second one',
#  b'good coconut oil purchas help keratosi pilari hasnt exact done job make skin feel nice doesnt get rid red like though',
#  b'tinkyada pasta amaz great textur consist tast doesnt add flavor arent expect way pasta made quinoa cook differ length get firmer softer pasta like wheat pasta high recommend tinkyada pasta found allerg wheat miss pasta dish dont miss pasta anymor wheat',
#  b'save money wish everyth product disappoint knew macadamia coconut two favorit thing could tast bad return seventeen three quarter eighteen purchas pleas',
#  b'nice bean wasnt sure would compar nice bean bought penzi spice compar happi purchas cant wait use get recommend mushroom vanilla bean friend',
#  b'use lavazza coffe capresso coffe excel smooth flavor bitter use stronger get without drink straight without sugar tast like',
#  b'dog friend dog love happ hip lamb rice christma gift',
#  b'say want greeni goe crazi favorit treat also help keep teeth clean breath less doggi',
#  b'dark chocol best eaten moder eat chocol natur qualiti quantiti issu individu packag due strength chocol flavor tend blend togeth due lack qualiti wrap need separ strong flavor chocol besid uniqu gift make someon feel special',
#  b'excel tea admit packag brand name extrem health put littl bit say proof pud tea perfect level flavor sweet natur sweet usual indic superior tea temperament term brew easili turn astring slight sure tea grown kudo farmer far better sever expens varieti order direct japan',
#  b'truffl great made thought price would greater tast didnt much tast worth price find buy truffl go spend fresh one',
#  b'product tast good buy wegman get place pay twenti six ship handl found freezer pack ripoff ask high ship respons fair snotti receiv product found label special select wegman sure enough next time went addit two contain expir two week ship cost make big ripoff get wegman',
#  b'great product although initi plan buy singl box sampl product realiz read previous review coconut water probabl acquir tast bought see end like first first tast seem rather bland somewhat warm next day drank anoth carton cold wasnt bad third day found look forward get home drink carton stuff love much ive subscrib regular deliveri mango flavor best wish littl cheaper thus star otherwis like product way high recommend anyon look light flavor altern soda',
#  b'soup isnt tradit pea soup expect thick rich pea flavor soup rather thin onion tast stronger split pea tast soup tasti nice textur healthi buy soup expect thick pea soup expect tasti soup ami doesnt make anyth bad good soup pea though',
#  b'got product expir date day receiv product hope give gift end throw away understand perish someth uned',
#  b'mayb yet found powder margarita mix like stuff tast bad margarita shack mix great hope stuff tast bitter artif lemon flavor dont want lemon flavor want slight sweet lime flavor love jose cuervo margarita mix island oasi wonder powder margarita mix tast bad good design good packag bad tast bud yuck',
#  b'happi satisfi purchas item glad make futur purchas',
#  b'love brand freez dri fruit found mango varieti lack flavor unlik mango juic mayb take juic fruit dri fiber satisfi',
#  b'expect tastier coffe one kinda flat cant drink quit better blend real dark roast coffe',
#  b'jerki driest ever come across crumbl soon put mouth tast terribl guess would abl get past textur better judg flavor even dog doesnt like jerki normal favorit treat',
#  b'posit delici love combin nut raisin bar sweet sweet enough remind adult candi bar without chocol ad benefit actual good',
#  b'thorough enjoy feel good bowl oatmeal boil coupl minut let cool day stay refriger overnight soak swell twenti minut simmer next day season unprocess salt miner littl pour appl cider vinegar mix togeth find dish delici time week uplift meal',
#  b'easi cook minut muffin maker ive even heat mix microwav melt chocol chip voila chocol muffin yum',
#  b'could use slight stronger vanilla flavor medium strength time funni aftertast good milk',
#  b'give product much even one star truffl essenc nose truffl tast big disappoint howev packag look promis folk amazon wonder deal soon call complain immedi refund money great custom servic would definit shop amazon',
#  b'cat storm love food although littl expens regular fanci feast think worth varieti supris like three normal eat chicken tuna eat',
#  b'pleasant surpris puerto rican partial prepar bean product good buy lot flavor excel would hesit use ethnic dish high recommend product',
#  b'love gift make tea time aesthet experi feel like mini trip spa beauti flower open aroma fragrant tea warm liquid creat moment pleasur',
#  b'abl find doubl bubbl chew gum regular basi area final connect candi crate abl order bulk granddaught wont chew anyth els order two day great servic',
#  b'great product easi deal order hassl great price ship fast could buyer ask seller',
#  b'receiv box candi reason amount time enjoy thank',
#  b'bob red mill gluten free product allow wheat gluten intoler eat food wise could would also recommend chocol cake mix browni mix miss bread contact red star yeast recip get bread machin bob red mill carri product youll need make bread good luck good eat fellow celiac suffer',
#  ...]

# %%
final['CleanedText']=final_string #adding a column of CleanedText which displays the data after pre-processing of the review

# %%
final.head(3) #below the processed review can be seen in the CleanedText Column 


# store final table into an SQlLite table for future.
conn = sqlite3.connect('final.sqlite')
c=conn.cursor()
conn.text_factory = str
final.to_sql('Reviews', conn, schema=None, if_exists='replace', index=True, index_label=None, chunksize=None, dtype=None)

# %%
final.shape
# Out:
# (19313, 11)

# %% [markdown]
# # Function for finding optimal K

# %% [raw]
# for finding optimal K we use 10 fold cross validation, we choose the best k on the train data.

# %%
from sklearn.cross_validation import cross_val_score

def find_optimal_k(X_train,y_train, myList):
   
    #creating odd list of K for KNN
    #myList = list(range(0,40))
    neighbors = list(filter(lambda x: x % 2 != 0, myList))

    # empty list that will hold cv scores
    cv_scores = []

    # perform 10-fold cross validation
    for k in neighbors:
        knn = KNeighborsClassifier(n_neighbors=k)
        scores = cross_val_score(knn, X_train, y_train, cv=10, scoring='accuracy')
        cv_scores.append(scores.mean())

    # changing to misclassification error
    MSE = [1 - x for x in cv_scores]

    # determining best k
    optimal_k = neighbors[MSE.index(min(MSE))]
    print('\nThe optimal number of neighbors is %d.' % optimal_k)


    plt.figure(figsize=(10,6))
    plt.plot(list(filter(lambda x: x % 2 != 0, myList)),MSE,color='blue', linestyle='dashed', marker='o',
             markerfacecolor='red', markersize=10)
    plt.title('Error Rate vs. K Value')
    plt.xlabel('K')
    plt.ylabel('Error Rate')

    print("the misclassification error for each k value is : ", np.round(MSE,3))
    
    return optimal_k

# %% [markdown]
# # BoW

# %%
# generating BoW matrix for text

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer()
final_bow_count = count_vect.fit_transform(final_string)

# %%
#standardizing the data

from sklearn.preprocessing import StandardScaler

final_bow_np = StandardScaler(with_mean=False).fit_transform(final_bow_count)

# %%
# train and test split

import math
from sklearn import datasets
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

X = final_bow_np
y = final['Score']

X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.3)
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
# Out:
# (13519, 17934) (13519,)
# (5794, 17934) (5794,)

# %%
# %%time
myList = list(range(0,30))

optimal_k = find_optimal_k(X_train ,y_train,myList)
# Out:
# The optimal number of neighbors is 23.
# the misclassification error for each k value is :  [0.314 0.28  0.265 0.259 0.253 0.249 0.246 0.245 0.245 0.244 0.245 0.242
#  0.242 0.243 0.244]
# CPU times: user 3min 1s, sys: 793 ms, total: 3min 2s
# Wall time: 3min 3s

# %%
# here the best k is 23.

# %%
# performing K-NN with the best/optimal K.

knn = KNeighborsClassifier(n_neighbors=23)
knn.fit(X_train, y_train)
pred = knn.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print("Accuracy for KNN model with Bag of words is ",round(accuracy_score(y_test ,pred),3))
# Out:
# Accuracy for KNN model with Bag of words is  0.743

# %% [markdown]
# # KNN with tf-idf
#  tf-idf vectors

# %%
# converting text to vectors by tf-idf method.
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
tf_idf_vec = TfidfVectorizer()

final_tfidf_count = tf_idf_vec.fit_transform(final_string)

# %%
from gensim.models import Word2Vec

# %%
# standardizing
from sklearn.preprocessing import StandardScaler

final_tfidf_np = StandardScaler(with_mean=False).fit_transform(final_tfidf_count )

# %%
# splitting the train and test datasets.

from sklearn import datasets
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import train_test_split

X = final_tfidf_np
y = final['Score']

X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.3)
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
# Out:
# (13519, 17934) (13519,)
# (5794, 17934) (5794,)

# %%
# finding best K which gives the least error.

myList = list(range(0,40))

optimal_k = find_optimal_k(X_train ,y_train,myList)
# Out:
# The optimal number of neighbors is 3.
# the misclassification error for each k value is :  [0.423 0.401 0.41  0.426 0.436 0.44  0.442 0.442 0.442 0.443 0.443 0.444
#  0.444 0.444 0.445 0.445 0.445 0.445 0.445 0.445]

# %%
# KNN with tf-idf for optimal K

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
pred = knn.predict(X_test)

# %%
print("Accuracy for KNN model with tf-idf is ",round(accuracy_score(y_test ,pred),3))
# Out:
# Accuracy for KNN model with tf-idf is  0.606

# %% [markdown]
# # KNN with AvgW2V

# %%
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
import pickle

# %%
import gensim
i=0
str1=''
list_of_sent=[]
final_string_for_tfidf = []
for sent in final['Text'].values:
    filtered_sentence=[]
    sent=cleanhtml(sent)
    str1 = ''
    for w in sent.split():
        for cleaned_words in cleanpunc(w).split():
            if((cleaned_words.isalpha()) & (cleaned_words.lower() not in stop)):    
                filtered_sentence.append(cleaned_words.lower())
                str1 += " "+cleaned_words.lower() 
            else:
                continue
    #str1 = b" ".join(filtered_sentence) #final string of cleaned words
            
    #final_string_for_tfidf.append(str1)
    list_of_sent.append(filtered_sentence)
    final_string_for_tfidf.append((str1).strip())

# %%
w2v_model=gensim.models.Word2Vec(list_of_sent,min_count=5,size=50, workers=4)

# %%
sent_vectors = []; 
for sent in list_of_sent: 
    sent_vec = np.zeros(50)
    cnt_words =0; 
    for word in sent: 
        try:
            vec = w2v_model.wv[word]
            sent_vec += vec
            cnt_words += 1
        except:
            pass
    sent_vec /= cnt_words
    sent_vectors.append(sent_vec)

# %%
import math
from sklearn import datasets
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import train_test_split

X = sent_vectors #final_w2v_count
y = final['Score']

X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.3)
#print (X_train.shape, y_train.shape)
#print (X_test.shape, y_test.shape)

# %%
myList = list(range(35,47))

optimal_k = find_optimal_k(X_train ,y_train,myList)
# Out:
# The optimal number of neighbors is 39.
# the misclassification error for each k value is :  [0.228 0.226 0.226 0.226 0.227 0.227]

# %%
#KNN with optimal K

knn = KNeighborsClassifier(n_neighbors=39)
knn.fit(X_train, y_train)
pred = knn.predict(X_test)

# %%
print("Accuracy for KNN model with Word2Vec is ",round(accuracy_score(y_test ,pred),3))
# Out:
# Accuracy for KNN model with Word2Vec is  0.782

# %% [markdown]
# # KNN with tf-ifd Weighted W2V

# %%
# td-idf vectors.

# %%
#from sklearn.feature_extraction.text import TfidfTransformer
#from sklearn.feature_extraction.text import TfidfVectorizer
tf_idf_vec_w = TfidfVectorizer()

final_tfidf_w = tf_idf_vec_w.fit_transform(final_string_for_tfidf)

# %%
tfidf_feat = tf_idf_vec_w.get_feature_names()


tfidf_sent_vectors = [];
row=0;
for sent in list_of_sent:  
    sent_vec = np.zeros(50) 
    weight_sum =0;
    for word in sent:
        try:
            vec = w2v_model.wv[word]
            tf_idf = final_tfidf_w[row, tfidf_feat.index(word)]
            sent_vec += (vec * tf_idf)
            weight_sum += tf_idf
        except Exception as e: 
            pass #print(e)
            
    try:
        sent_vec /= weight_sum
    except:
        print(e)
        
    tfidf_sent_vectors.append(sent_vec)
    row += 1

# %%
# splitting the dataset

from sklearn import datasets
from sklearn.neighbors import KNeighborsClassifier


X = tfidf_sent_vectors
y = final['Score']

X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.3)

# %%
# finding optimal K

# %%
# %%time
myList = list(range(0,40))

optimal_k = find_optimal_k(X_train ,y_train,myList)
# Out:
# The optimal number of neighbors is 23.
# the misclassification error for each k value is :  [0.314 0.28  0.265 0.259 0.253 0.249 0.246 0.245 0.245 0.244 0.245 0.242
#  0.242 0.243 0.244 0.247 0.245 0.244 0.245 0.245]
# CPU times: user 3min 57s, sys: 559 ms, total: 3min 57s
# Wall time: 3min 58s

# %%
# KNN with optimal K

knn = KNeighborsClassifier(n_neighbors=23)
knn.fit(X_train, y_train)
pred = knn.predict(X_test)

# %%
# printing accuracy

print("Accuracy for KNN model with tf-idf weighted Word2vec ",round(accuracy_score(y_test ,pred),3))
# Out:
# Accuracy for KNN model with tf-idf weighted Word2vec  0.743

# %% [markdown]
# Final Observation:
#
# 1) Out of these 4 methods of converting text to vector, the K-NN classifier prediction has acheived the best accuracy
#    of 78% on Avg W2V model which is greatest among all other conversions.
